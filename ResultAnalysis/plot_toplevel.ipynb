# %%
from datawrapper import VFDataWrapper, VFDataWrapperExtraction
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
farm3264 = 'arm32vsarm64.csv'
farmbase = 'arm32inorder.csv'
d3264 = VFDataWrapperExtraction('arm32vsarm64.csv', [])
d32io = VFDataWrapperExtraction('arm32inorder.csv', [])
df3264 = d3264.readpvfbytime()
df32io = d32io.readpvfbytime()

# %%
mask_mmb_unroll = d32io.getsweepinfo('matrixmult_blockunroll')

# %%
mask_mmb_unroll.plot(x='Tick')
# Out:
# <AxesSubplot:xlabel='Tick'>

# %%
mask_mmb = d32io.getsweepinfo('matrixmultb_')

# %%
mask_mmb.plot(x='Tick')
# Out:
# <AxesSubplot:xlabel='Tick'>

# %%
mask_qsort50 = d32io.getsweepinfo('qsortvec50')

# %%
mask_susan3unroll = d32io.getsweepinfo('susan_s3unroll')

# %%
mask_susans4 = d32io.getsweepinfo('susan_s4')

# %%
mask_susans4.plot(x='Tick')
# Out:
# <AxesSubplot:xlabel='Tick'>
